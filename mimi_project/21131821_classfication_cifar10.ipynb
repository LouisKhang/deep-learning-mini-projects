# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()


x_train, x_test = x_train / 255.0, x_test / 255.0


y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

datagen.fit(x_train)


model = models.Sequential()

model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(256, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.3))  # Giảm tỷ lệ dropout xuống 30%

model.add(layers.Dense(10, activation='softmax'))


model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.75, patience=2, min_lr=0.0001)


history = model.fit(datagen.flow(x_train, y_train, batch_size=64),
                    epochs=15,
                    validation_data=(x_test, y_test),
                    callbacks=[reduce_lr])


test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 47ms/step - accuracy: 0.3070 - loss: 1.8418 - val_accuracy: 0.5591 - val_loss: 1.2276 - learning_rate: 0.0010
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.5369 - loss: 1.2977 - val_accuracy: 0.6257 - val_loss: 1.0589 - learning_rate: 0.0010
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.6058 - loss: 1.1035 - val_accuracy: 0.6687 - val_loss: 0.9247 - learning_rate: 0.0010
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.6542 - loss: 0.9942 - val_accuracy: 0.6944 - val_loss: 0.8838 - learning_rate: 0.0010
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.6807 - loss: 0.9122 - val_accuracy: 0.6964 - val_loss: 0.8711 - learning_rate: 0.0010
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.6975 - loss: 0.8680 - val_accuracy: 0.7334 - val_loss: 0.7641 - learning_rate: 0.0010
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.7134 - loss: 0.8219 - val_accuracy: 0.7414 - val_loss: 0.7447 - learning_rate: 0.0010
# Epoch 8/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.7266 - loss: 0.7887 - val_accuracy: 0.7345 - val_loss: 0.7721 - learning_rate: 0.0010
# Epoch 9/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.7371 - loss: 0.7562 - val_accuracy: 0.7444 - val_loss: 0.7588 - learning_rate: 0.0010
# Epoch 10/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7539 - loss: 0.7091 - val_accuracy: 0.7584 - val_loss: 0.7353 - learning_rate: 7.5000e-04
# Epoch 11/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.7606 - loss: 0.6853 - val_accuracy: 0.7423 - val_loss: 0.7586 - learning_rate: 7.5000e-04
# Epoch 12/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.7665 - loss: 0.6634 - val_accuracy: 0.7739 - val_loss: 0.6659 - learning_rate: 7.5000e-04
# Epoch 13/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7725 - loss: 0.6430 - val_accuracy: 0.7923 - val_loss: 0.6119 - learning_rate: 7.5000e-04
# Epoch 14/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.7771 - loss: 0.6338 - val_accuracy: 0.7990 - val_loss: 0.6011 - learning_rate: 7.5000e-04
# Epoch 15/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.7821 - loss: 0.6226 - val_accuracy: 0.7798 - val_loss: 0.6550 - learning_rate: 7.5000e-04
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7818 - loss: 0.6495
# Test accuracy: 0.7797999978065491

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)

print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7818 - loss: 0.6495
# Test accuracy: 77.98%
